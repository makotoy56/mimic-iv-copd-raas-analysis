# %% [raw]
# \setcounter{secnumdepth}{0}

# %% [markdown]
# # 01 - ICU Cohort Extraction
#
# Short summary:
# [01 - ICU Cohort Extraction (SHORT)](../docs/01_icu_cohort_SHORT.md)
#
# ----
#
# ## 1. Objective
# Build the base ICU cohort from MIMIC-IV using BigQuery and verify the integrity of the extracted ICU-stay-level tables.
#
# ----
#
# ## 2. Data Processing Steps

# %% [markdown]
# ### 2.1 Common BigQuery Utilities

# %%
# Use Application Default Credentials (my user account)
# This account already has PhysioNet BigQuery access.

from google.cloud import bigquery
from google.auth import default
from pathlib import Path

# Define project ID
PROJECT_ID = "mimic-iv-portfolio"

# Get ADC credentials
creds, adc_project = default()

# Initialize BigQuery client
client = bigquery.Client(project=PROJECT_ID, credentials=creds)

print("Connected to BigQuery project:", PROJECT_ID)
print("ADC default project:", adc_project)

# Helper to run a SQL script file (DDL, CREATE TABLE, etc.)
def run_sql_script(path) :
    """
    Read a .sql file from disk, execute it in BigQuery,
    and wait until the job finishes.
    Use this for CREATE TABLE / INSERT INTO scripts.
    """
    sql_path = Path(path)
    with sql_path.open("r") as f:
        query = f.read()
    job = client.query(query)
    job.result()
    print(f"Executed SQL script: {sql_path.name}")

# Helper for SELECT queries → DataFrame
def query_to_df(query) :
    """
    Run a SELECT query in BigQuery and return a pandas DataFrame.
    """
    job = client.query(query)
    return job.to_dataframe(create_bqstorage_client=False)

# %% [markdown]
# ### 2.2 Build Cohort Tables in BigQuery

# %%
# Excecute SQL script (01_extract_base.sql)
run_sql_script("../sql/01_extract_base.sql")

# %% [markdown]
# ### 2.3 Sanity Checks

# %%
# Sanity checks for the created base ICU cohort table
# Row-level data are loaded for schema validation only; no rows are displayed.
df_cohort_icu = query_to_df("""
    SELECT *
    FROM `mimic-iv-portfolio.copd_raas.cohort_icu`
""")

df_cohort_icu.info()
print("Shape:", df_cohort_icu.shape)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Output Dataset
#
# **Input Dataset**
# - MIMIC-IV ICU stay and patient tables in BigQuery.
#
# **Output Dataset**
# - `mimic-iv-portfolio.copd_raas.cohort_icu`
#
# **Downstream Usage**
# - This ICU-stay-level table is the base cohort input for COPD cohort construction in `02_cohort_and_exposures.ipynb`.

# %% [markdown]
# ---

# %% [markdown]
# ## Next Step
#
# Proceed to:
# - [02 - Cohort and Exposure Construction](02_cohort_and_exposures.ipynb)
#
# This next notebook defines the COPD ICU cohort and pre-ICU RAAS exposure indicators.
